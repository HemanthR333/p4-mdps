# %%
#!pip install tensorflow pandas streamlit numpy matplot

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from keras import layers

# %%
data_train_path = "Split_smol/train"
#data_train_test = "Split_smol/test" 
data_train_val = "Split_smol/val"

# %%
img_width = 160
img_height = 160

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle = True,
    image_size = (img_width, img_height),
    batch_size = 32,
    validation_split = False
)
# Out:
# Found 754 files belonging to 10 classes.

# %%
data_cat = data_train.class_names

# %%
data_val = tf.keras.utils.image_dataset_from_directory(
    data_train_val,
    shuffle = False,
    image_size = (img_width, img_height),
    batch_size = 32,
    validation_split = False

)
# Out:
# Found 238 files belonging to 10 classes.

# %%
#data_test = tf.keras.utils.image_dataset_from_directory(
#    data_train_test,
 #   shuffle = False,
  #  image_size = (img_width, img_height),
   # batch_size = 32,
    #validation_split = False
#)

# %%
plt.figure(figsize=(10,10))
for image , labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %%
from keras.models import Sequential

# %%
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))
])

# %%
model.compile(optimizer = 'adam' , loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics = ['accuracy'])

# %%
history = model.fit(data_train, validation_data = data_val , epochs = 25)
# Out:
# Epoch 1/25
# 24/24 [==============================] - 12s 414ms/step - loss: 2.7741 - accuracy: 0.1499 - val_loss: 1.9435 - val_accuracy: 0.4076
# Epoch 2/25
# 24/24 [==============================] - 10s 400ms/step - loss: 1.8287 - accuracy: 0.3660 - val_loss: 1.4684 - val_accuracy: 0.4538
# Epoch 3/25
# 24/24 [==============================] - 10s 395ms/step - loss: 1.4185 - accuracy: 0.5000 - val_loss: 1.5370 - val_accuracy: 0.4328
# Epoch 4/25
# 24/24 [==============================] - 10s 395ms/step - loss: 1.2171 - accuracy: 0.5584 - val_loss: 1.1400 - val_accuracy: 0.6134
# Epoch 5/25
# 24/24 [==============================] - 10s 397ms/step - loss: 0.8939 - accuracy: 0.6631 - val_loss: 1.0100 - val_accuracy: 0.6723
# Epoch 6/25
# 24/24 [==============================] - 11s 433ms/step - loss: 0.8121 - accuracy: 0.7042 - val_loss: 1.0060 - val_accuracy: 0.6807
# Epoch 7/25
# 24/24 [==============================] - 10s 396ms/step - loss: 0.7463 - accuracy: 0.7281 - val_loss: 0.9246 - val_accuracy: 0.7101
# Epoch 8/25
# 24/24 [==============================] - 10s 397ms/step - loss: 0.6125 - accuracy: 0.7772 - val_loss: 0.9510 - val_accuracy: 0.7101
# Epoch 9/25
# 24/24 [==============================] - 10s 412ms/step - loss: 0.5432 - accuracy: 0.8011 - val_loss: 1.0359 - val_accuracy: 0.7059
# Epoch 10/25
# 24/24 [==============================] - 10s 394ms/step - loss: 0.5093 - accuracy: 0.8196 - val_loss: 0.9742 - val_accuracy: 0.7227
# Epoch 11/25
# 24/24 [==============================] - 11s 414ms/step - loss: 0.4929 - accuracy: 0.8223 - val_loss: 1.1820 - val_accuracy: 0.6975
# Epoch 12/25
# 24/24 [==============================] - 11s 433ms/step - loss: 0.4495 - accuracy: 0.8435 - val_loss: 1.1941 - val_accuracy: 0.6765
# Epoch 13/25
# 24/24 [==============================] - 10s 402ms/step - loss: 0.3913 - accuracy: 0.8568 - val_loss: 1.1956 - val_accuracy: 0.7227
# Epoch 14/25
# 24/24 [==============================] - 10s 404ms/step - loss: 0.3704 - accuracy: 0.8780 - val_loss: 1.2695 - val_accuracy: 0.6975
# Epoch 15/25
# 24/24 [==============================] - 10s 400ms/step - loss: 0.2813 - accuracy: 0.9204 - val_loss: 1.1008 - val_accuracy: 0.7101
# Epoch 16/25
# 24/24 [==============================] - 10s 399ms/step - loss: 0.2483 - accuracy: 0.9191 - val_loss: 1.2723 - val_accuracy: 0.7101
# Epoch 17/25
# 24/24 [==============================] - 10s 408ms/step - loss: 0.2070 - accuracy: 0.9310 - val_loss: 1.3679 - val_accuracy: 0.7311
# Epoch 18/25
# 24/24 [==============================] - 11s 419ms/step - loss: 0.1650 - accuracy: 0.9443 - val_loss: 1.3727 - val_accuracy: 0.7227
# Epoch 19/25
# 24/24 [==============================] - 10s 397ms/step - loss: 0.1708 - accuracy: 0.9496 - val_loss: 1.3486 - val_accuracy: 0.7017
# Epoch 20/25
# 24/24 [==============================] - 10s 398ms/step - loss: 0.1292 - accuracy: 0.9668 - val_loss: 1.3599 - val_accuracy: 0.7227
# Epoch 21/25
# 24/24 [==============================] - 10s 400ms/step - loss: 0.1728 - accuracy: 0.9496 - val_loss: 1.2835 - val_accuracy: 0.7395
# Epoch 22/25
# 24/24 [==============================] - 11s 425ms/step - loss: 0.1433 - accuracy: 0.9509 - val_loss: 1.4575 - val_accuracy: 0.6765
# Epoch 23/25
# 24/24 [==============================] - 11s 420ms/step - loss: 0.1630 - accuracy: 0.9430 - val_loss: 1.6096 - val_accuracy: 0.7101
# Epoch 24/25
# 24/24 [==============================] - 10s 401ms/step - loss: 0.3562 - accuracy: 0.8939 - val_loss: 1.4014 - val_accuracy: 0.7101
# Epoch 25/25
# 24/24 [==============================] - 10s 403ms/step - loss: 0.2470 - accuracy: 0.9257 - val_loss: 1.5019 - val_accuracy: 0.6891

# %%
data_val
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
epochs_range = range(25)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range,history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range,history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
image = '1.jpg'
image = tf.keras.utils.load_img(image , target_size = (img_height, img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat = tf.expand_dims(img_arr,0)

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 [==============================] - 0s 158ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print("Skin Disease in the image is {} with an accuracy of {:0.2f}".format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Skin Disease in the image is Tinea Ringworm Candidiasis with an accuracy of 99.99

# %%
model.save('Skin.h5')
# Out:
# C:\Users\Hemanth R\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
data_cat
# Out:
# ['Actinic keratosis',
#  'Atopic Dermatitis',
#  'Benign keratosis',
#  'Dermatofibroma',
#  'Melanocytic nevus',
#  'Melanoma',
#  'Squamous cell carcinoma',
#  'Tinea Ringworm Candidiasis',
#  'Vascular lesion',
#  'normal skin']

# %%
#!pip install streamlit

# %%
#!pip install streamlit-option-menu

# %%
#!streamlit run "app1.py"
